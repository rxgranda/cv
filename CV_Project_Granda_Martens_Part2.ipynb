# %%
from lxml import etree
import numpy as np
import os
from skimage import io
from skimage.transform import resize
from keras.layers import Input, Dense
from keras.models import Model
import numpy as np
import pandas as pd
import tensorflow as tf
from skimage.color import rgb2gray
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D,BatchNormalization,Activation, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint

import os.path

from keras.models import Model
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17968104314963384157
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1458703155
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5319424677521453274
# physical_device_desc: "device: 0, name: GeForce MX150, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %% [markdown]
# ### Loading Dataset

# %%
# parameters that you should set before running this script
filter = ['plane', 'cat'] #, 'chair', 'dog', 'bird']       # select class, this default should yield 1489 training and 1470 validation images
voc_root_folder = "../VOCdevkit/"  # please replace with the location on your laptop where you unpacked the tarball
image_size = 256    # image size that you will use for your network (input images will be resampled to this size), lower if you have troubles on your laptop (hint: use io.imshow to inspect the quality of the resampled images before feeding it into your network!)


# step1 - build list of filtered filenames
annotation_folder = os.path.join(voc_root_folder, "VOC2009/Annotations/")
annotation_files = os.listdir(annotation_folder)
filtered_filenames = []
for a_f in annotation_files:
    tree = etree.parse(os.path.join(annotation_folder, a_f))
    if np.any([tag.text == filt for tag in tree.iterfind(".//name") for filt in filter]):
        filtered_filenames.append(a_f[:-4])

# step2 - build (x,y) for TRAIN/VAL (classification)
classes_folder = os.path.join(voc_root_folder, "VOC2009/ImageSets/Main/")
classes_files = os.listdir(classes_folder)
train_files = [os.path.join(classes_folder, c_f) for filt in filter for c_f in classes_files if filt in c_f and '_train.txt' in c_f]
val_files = [os.path.join(classes_folder, c_f) for filt in filter for c_f in classes_files if filt in c_f and '_val.txt' in c_f]

train_filter=[]
def build_classification_dataset(list_of_files):
    """ build training or validation set

    :param list_of_files: list of filenames to build trainset with
    :return: tuple with x np.ndarray of shape (n_images, image_size, image_size, 3) and  y np.ndarray of shape (n_images, n_classes)
    """
    temp = []
    train_labels = []
    for f_cf in list_of_files:
        with open(f_cf) as file:
            lines = file.read().splitlines()
            temp.append([line.split()[0] for line in lines if int(line.split()[-1]) == 1])
            label_id = [f_ind for f_ind, filt in enumerate(filter) if filt in f_cf][0]
            train_labels.append(len(temp[-1]) * [label_id])
    train_filter = [item for l in temp for item in l]

    image_folder = os.path.join(voc_root_folder, "VOC2009/JPEGImages/")
    image_filenames = [os.path.join(image_folder, file) for f in train_filter for file in os.listdir(image_folder) if
                       f in file]
    #print(image_filenames)
    mask_files=[]
    
    #print(mask_files)
    x = np.array([resize(io.imread(img_f), (image_size, image_size, 3)) for img_f in image_filenames]).astype(
        'float32')
    # changed y to an array of shape (num_examples, num_classes) with 0 if class is not present and 1 if class is present
    y_temp = []
    for tf in train_filter:
        y_temp.append([1 if tf in l else 0 for l in temp])
    y = np.array(y_temp)

    return x, y




x_train, y_train = build_classification_dataset(train_files)

print('%i training images from %i classes ' %(x_train.shape[0], y_train.shape[1]))
x_val, y_val = build_classification_dataset(val_files)
print('%i validation images from %i classes' %(x_val.shape[0],  y_train.shape[1]))

# from here, you can start building your model
# you will only need x_train and x_val for the autoencoder
# you should extend the above script for the segmentation task (you will need a slightly different function for building the label images)
# Out:
# 467 training images from 2 classes
# 483 validation images from 2 classes

# %%
def build_segmentation_dataset(list_of_files):
    """ build training or validation set

    :param list_of_files: list of filenames to build trainset with
    :return: tuple with x np.ndarray of shape (n_images, image_size, image_size, 3) and  y np.ndarray of shape (n_images, n_classes)
    """
    temp = []
    train_labels = []
    for f_cf in list_of_files:
        with open(f_cf) as file:
            lines = file.read().splitlines()
            temp.append([line.split()[0] for line in lines if int(line.split()[-1]) == 1])
            label_id = [f_ind for f_ind, filt in enumerate(filter) if filt in f_cf][0]
            train_labels.append(len(temp[-1]) * [label_id])
    train_filter = [item for l in temp for item in l]

    image_folder = os.path.join(voc_root_folder, "VOC2009/JPEGImages/")
    image_filenames = [os.path.join(image_folder, file) for f in train_filter for file in os.listdir(image_folder) if
                       f in file]
    #print(image_filenames)
    mask_files=[]
    new_image_filenames=[]
    for i in image_filenames:        
        j=i.replace("JPEGImages", "SegmentationClass")
        j=j[:-3]+"png"
        if os.path.exists(j):
            mask_files.append(j)
            new_image_filenames.append(i)
    image_filenames=new_image_filenames
    #print(mask_files)
    x = np.array([resize(io.imread(img_f), (image_size, image_size, 3)) for img_f in image_filenames]).astype(
        'float32')
    x_mask = np.array([resize(io.imread(img_f), (image_size, image_size, 3)) for img_f in mask_files]).astype(
        'float32')
    
    x_mask_0=np.zeros((x_mask.shape[0],x_mask.shape[1],x_mask.shape[2],1))
    for i in range(x_mask.shape[0]):
        x_mask_0[i]=np.expand_dims(x_mask[i,:,:,0],axis=3)
        
        
    # changed y to an array of shape (num_examples, num_classes) with 0 if class is not present and 1 if class is present
    y_temp = []
    for tf in train_filter:
        y_temp.append([1 if tf in l else 0 for l in temp])
    y = np.array(y_temp)

    return x, y,x_mask_0


x_train_mask, y_train_mask_label,mask_train = build_segmentation_dataset(train_files)

print('%i training images from %i classes and %i masks' %(x_train_mask.shape[0], y_train_mask_label.shape[1],mask_train.shape[0]))
x_val_mask, y_val_mask_label ,mask_val= build_segmentation_dataset(val_files)
print('%i validation images from %i classes and %i masks' %(x_val_mask.shape[0],  y_val_mask_label.shape[1],mask_val.shape[0]))
# Out:
# C:\Users\HP\Desktop\Thesis\cleverhans\env\lib\site-packages\ipykernel_launcher.py:38: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
# 48 training images from 2 classes and 48 masks
# 53 validation images from 2 classes and 53 masks

# %%
import matplotlib.pyplot as plt

n = 5  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(mask_train[i].reshape(image_size, image_size)) 
plt.show()

# %% [markdown]
# ## Part 2.2 Non Linear and Convolutional

# %%
input_img = Input(shape=(image_size, image_size, 3))  # adapt this if using `channels_first` image data format

x = Conv2D(64, (5, 5), activation='relu', padding='same',strides=(2,2))(input_img)
x = BatchNormalization()(x)
#x = MaxPooling2D((2, 2), padding='same')(x)
#x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
#x = MaxPooling2D((2, 2), padding='same')(x)
#x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(300, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(300, (3, 3), activation='relu', padding='same')(encoded)
x = BatchNormalization()(x)
x = UpSampling2D((4, 4))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
#x = UpSampling2D((2, 2))(x)
#x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(3, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
decoded = Activation('linear')(x)
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='mse')
from datetime import datetime
import keras
logdir="./tmp/autoencoder" + datetime.now().strftime("%Y%m%d-%H%M%S")
#tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

encoder = Model(input_img, encoded)

es_cb = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
chkpt = './AutoEncoderREDO_PASCAL_Deep_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')


print(autoencoder.summary())

 #callbacks=[tensorboard_callback]
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      4864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 300)       345900
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 300)       1200
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 300)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 300)       810300
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 300)       1200
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 300)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 128)       345728
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 64)      73792
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 256, 256, 3)       1731
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 256, 256, 3)       12
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 256, 3)       0
# =================================================================
# Total params: 1,660,119
# Trainable params: 1,658,145
# Non-trainable params: 1,974
# _________________________________________________________________
# None

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=10,
                shuffle=True,
                validation_data=(x_val, x_val),
                                    callbacks=[es_cb, cp_cb]
               )
# Out:
# Train on 467 samples, validate on 483 samples
# Epoch 1/50
# 467/467 [==============================] - 36s 76ms/step - loss: 0.7694 - val_loss: 0.7715
#
# Epoch 00001: val_loss improved from inf to 0.77152, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.01-0.77-0.77.hdf5
# Epoch 2/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.5992 - val_loss: 0.6774
#
# Epoch 00002: val_loss improved from 0.77152 to 0.67736, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.02-0.60-0.68.hdf5
# Epoch 3/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.4802 - val_loss: 0.5162
#
# Epoch 00003: val_loss improved from 0.67736 to 0.51624, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.03-0.48-0.52.hdf5
# Epoch 4/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.3817 - val_loss: 0.3067
#
# Epoch 00004: val_loss improved from 0.51624 to 0.30665, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.04-0.38-0.31.hdf5
# Epoch 5/50
# 467/467 [==============================] - 30s 63ms/step - loss: 0.2967 - val_loss: 0.3157
#
# Epoch 00005: val_loss did not improve from 0.30665
# Epoch 6/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.2316 - val_loss: 0.2665
#
# Epoch 00006: val_loss improved from 0.30665 to 0.26655, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.06-0.23-0.27.hdf5
# Epoch 7/50
# 467/467 [==============================] - 29s 62ms/step - loss: 0.1760 - val_loss: 0.1451
#
# Epoch 00007: val_loss improved from 0.26655 to 0.14514, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.07-0.18-0.15.hdf5
# Epoch 8/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.1318 - val_loss: 0.1361
#
# Epoch 00008: val_loss improved from 0.14514 to 0.13611, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.08-0.13-0.14.hdf5
# Epoch 9/50
# 467/467 [==============================] - 30s 63ms/step - loss: 0.0959 - val_loss: 0.0720
#
# Epoch 00009: val_loss improved from 0.13611 to 0.07196, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.09-0.10-0.07.hdf5
# Epoch 10/50
# 467/467 [==============================] - 30s 64ms/step - loss: 0.0703 - val_loss: 0.1030
#
# Epoch 00010: val_loss did not improve from 0.07196
# Epoch 11/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0506 - val_loss: 0.0312
#
# Epoch 00011: val_loss improved from 0.07196 to 0.03122, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.11-0.05-0.03.hdf5
# Epoch 12/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0348 - val_loss: 0.0287
#
# Epoch 00012: val_loss improved from 0.03122 to 0.02867, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.12-0.03-0.03.hdf5
# Epoch 13/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0243 - val_loss: 0.0183
#
# Epoch 00013: val_loss improved from 0.02867 to 0.01827, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.13-0.02-0.02.hdf5
# Epoch 14/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0176 - val_loss: 0.0107
#
# Epoch 00014: val_loss improved from 0.01827 to 0.01069, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.14-0.02-0.01.hdf5
# Epoch 15/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0134 - val_loss: 0.0084
#
# Epoch 00015: val_loss improved from 0.01069 to 0.00840, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.15-0.01-0.01.hdf5
# Epoch 16/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0109 - val_loss: 0.0087
#
# Epoch 00016: val_loss did not improve from 0.00840
# Epoch 17/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0093 - val_loss: 0.0070
#
# Epoch 00017: val_loss improved from 0.00840 to 0.00701, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.17-0.01-0.01.hdf5
# Epoch 18/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0098 - val_loss: 0.0074
#
# Epoch 00018: val_loss did not improve from 0.00701
# Epoch 19/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0094 - val_loss: 0.0069
#
# Epoch 00019: val_loss improved from 0.00701 to 0.00687, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.19-0.01-0.01.hdf5
# Epoch 20/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0094 - val_loss: 0.0073
#
# Epoch 00020: val_loss did not improve from 0.00687
# Epoch 21/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0095 - val_loss: 0.0070
#
# Epoch 00021: val_loss did not improve from 0.00687
# Epoch 22/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0093 - val_loss: 0.0075
#
# Epoch 00022: val_loss did not improve from 0.00687
# Epoch 23/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0090 - val_loss: 0.0068
#
# Epoch 00023: val_loss improved from 0.00687 to 0.00677, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.23-0.01-0.01.hdf5
# Epoch 24/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0102 - val_loss: 0.0119
#
# Epoch 00024: val_loss did not improve from 0.00677
# Epoch 25/50
# 467/467 [==============================] - 30s 64ms/step - loss: 0.0093 - val_loss: 0.0069
#
# Epoch 00025: val_loss did not improve from 0.00677
# Epoch 26/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0092 - val_loss: 0.0070
#
# Epoch 00026: val_loss did not improve from 0.00677
# Epoch 27/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0088 - val_loss: 0.0069
#
# Epoch 00027: val_loss did not improve from 0.00677
# Epoch 28/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0094 - val_loss: 0.0068
#
# Epoch 00028: val_loss did not improve from 0.00677
# Epoch 29/50
# 467/467 [==============================] - 30s 63ms/step - loss: 0.0090 - val_loss: 0.0066
#
# Epoch 00029: val_loss improved from 0.00677 to 0.00663, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.29-0.01-0.01.hdf5
# Epoch 30/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0094 - val_loss: 0.0068
#
# Epoch 00030: val_loss did not improve from 0.00663
# Epoch 31/50
# 467/467 [==============================] - 30s 63ms/step - loss: 0.0087 - val_loss: 0.0068
#
# Epoch 00031: val_loss did not improve from 0.00663
# Epoch 32/50
# 467/467 [==============================] - 30s 63ms/step - loss: 0.0090 - val_loss: 0.0064
#
# Epoch 00032: val_loss improved from 0.00663 to 0.00641, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.32-0.01-0.01.hdf5
# Epoch 33/50
# 467/467 [==============================] - 30s 65ms/step - loss: 0.0099 - val_loss: 0.0065
#
# Epoch 00033: val_loss did not improve from 0.00641
# Epoch 34/50
# 467/467 [==============================] - 30s 64ms/step - loss: 0.0091 - val_loss: 0.0066
#
# Epoch 00034: val_loss did not improve from 0.00641
# Epoch 35/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0088 - val_loss: 0.0064
#
# Epoch 00035: val_loss did not improve from 0.00641
# Epoch 36/50
# 467/467 [==============================] - 30s 64ms/step - loss: 0.0087 - val_loss: 0.0064
#
# Epoch 00036: val_loss improved from 0.00641 to 0.00641, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.36-0.01-0.01.hdf5
# Epoch 37/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0088 - val_loss: 0.0064
#
# Epoch 00037: val_loss did not improve from 0.00641
# Epoch 38/50
# 467/467 [==============================] - 30s 64ms/step - loss: 0.0086 - val_loss: 0.0063
#
# Epoch 00038: val_loss improved from 0.00641 to 0.00632, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.38-0.01-0.01.hdf5
# Epoch 39/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0093 - val_loss: 0.0065
#
# Epoch 00039: val_loss did not improve from 0.00632
# Epoch 40/50
# 467/467 [==============================] - 30s 63ms/step - loss: 0.0084 - val_loss: 0.0062
#
# Epoch 00040: val_loss improved from 0.00632 to 0.00625, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.40-0.01-0.01.hdf5
# Epoch 41/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0088 - val_loss: 0.0063
#
# Epoch 00041: val_loss did not improve from 0.00625
# Epoch 42/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0083 - val_loss: 0.0065
#
# Epoch 00042: val_loss did not improve from 0.00625
# Epoch 43/50
# 467/467 [==============================] - 30s 63ms/step - loss: 0.0084 - val_loss: 0.0062
#
# Epoch 00043: val_loss improved from 0.00625 to 0.00624, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.43-0.01-0.01.hdf5
# Epoch 44/50
# 467/467 [==============================] - 30s 64ms/step - loss: 0.0086 - val_loss: 0.0062
#
# Epoch 00044: val_loss improved from 0.00624 to 0.00620, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.44-0.01-0.01.hdf5
# Epoch 45/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0087 - val_loss: 0.0062
#
# Epoch 00045: val_loss did not improve from 0.00620
# Epoch 46/50
# 467/467 [==============================] - 29s 63ms/step - loss: 0.0084 - val_loss: 0.0062
#
# Epoch 00046: val_loss improved from 0.00620 to 0.00616, saving model to ./AutoEncoderREDO_PASCAL_Deep_weights.46-0.01-0.01.hdf5
# Epoch 47/50
# 467/467 [==============================] - 30s 64ms/step - loss: 0.0089 - val_loss: 0.0074
#
# Epoch 00047: val_loss did not improve from 0.00616
# Epoch 48/50
# 467/467 [==============================] - 30s 64ms/step - loss: 0.0084 - val_loss: 0.0062
#
# Epoch 00048: val_loss did not improve from 0.00616
# Epoch 49/50
# 467/467 [==============================] - 30s 65ms/step - loss: 0.0080 - val_loss: 0.0062
#
# Epoch 00049: val_loss did not improve from 0.00616
# Epoch 50/50
# 467/467 [==============================] - 30s 64ms/step - loss: 0.0091 - val_loss: 0.0062
#
# Epoch 00050: val_loss did not improve from 0.00616

# %%
decoded_imgs = autoencoder.predict(x_val)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_val[i].reshape(image_size, image_size,3)) 
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(image_size, image_size,3) )
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#print(autoencoder.history.history)
loss = autoencoder.history.history['loss']
val_loss = autoencoder.history.history['val_loss']
epochs = range(50)
plt.figure()
plt.plot(epochs, loss, 'darkorange', label='Training loss')
plt.plot(epochs, val_loss, 'dodgerblue', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel("Mean Squared Error")
plt.xlabel("Epochs")
plt.legend()
plt.show()
# Out:
# {'val_loss': [0.7720381267075707, 0.6799220757454819, 0.5254087689377013, 0.3845853804924967, 0.3449452409277792, 0.1999796224183424, 0.17389881410337135, 0.11949228486104041, 0.08776758213220916, 0.057920962448692714, 0.04256176845195624, 0.03273936069144349, 0.0242437744786959, 0.012518561287063867, 0.009889656791606182, 0.00891218800097704, 0.0074640991278069856, 0.006973608288967955, 0.007033330949474566, 0.007598967708870923, 0.006824732906576516, 0.007034505062831053, 0.007508505533948756, 0.006811025023159588, 0.00695698382332921, 0.006801839014534562, 0.006736129068231546, 0.006691097753319126, 0.007333627982955912, 0.007010299735557959, 0.007339055419515811, 0.006921317762893858, 0.006415006167623629, 0.007259424102895625, 0.006976359268345756, 0.006420391871098344, 0.007082050778048873, 0.006705052265608163, 0.006375671609248928, 0.006482259361709682, 0.006431369057916274, 0.006631646809548016, 0.0064493637449083, 0.006323010638533603, 0.006711762194091735, 0.010991413568534095, 0.006686672023603573, 0.006810660204053789, 0.006378169195614678, 0.006148342480863721], 'loss': [0.7743450169644979, 0.603090133095196, 0.4837611960267102, 0.3810066483771265, 0.3023129190443925, 0.23292999847032272, 0.17864861414315103, 0.13495455508377618, 0.10120447506485966, 0.07117160320345799, 0.05208306844950488, 0.03527843616344434, 0.02592758991111397, 0.01830752488281538, 0.013195536294812436, 0.011079337673233842, 0.009955491280338749, 0.009980148594922184, 0.009335883334677914, 0.009072324332862902, 0.009444719455673557, 0.009816982350621284, 0.00955489305659682, 0.010034951317568791, 0.008977997940376688, 0.008965424312841011, 0.009055086770503757, 0.009514776341680924, 0.009512229887389716, 0.008574761366531475, 0.008536868419585952, 0.008891794880417353, 0.009461359948526102, 0.00929933528134667, 0.00883056185700845, 0.009448868421961331, 0.008743239199738686, 0.009012865329388633, 0.008547364819866687, 0.009886005991068718, 0.00957483175256523, 0.009105133516933346, 0.009360096578903066, 0.009319820379483368, 0.008231941168844636, 0.009171413022394609, 0.00853228051917392, 0.009187795233771173, 0.008977229214359147, 0.008953900460345268]}

# %%
np.max(decoded_imgs)
# Out:
# 1.465262

# %%
encoded_imgs = encoder.predict(x_val)
print(encoded_imgs.shape)
encoded_imgs = encoded_imgs.reshape((len(encoded_imgs), np.prod(encoded_imgs.shape[1:])))
print(encoded_imgs.shape)
y_val2=y_val[:,0]
# Out:
# (483, 16, 16, 300)
# (483, 76800)

# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
# %matplotlib inline

import seaborn as sns
sns.set_style('darkgrid')
sns.set_palette('muted')
sns.set_context("notebook", font_scale=1.5,
                rc={"lines.linewidth": 2.5})
RS = 123


def fashion_scatter(x, colors):
    # choose a color palette with seaborn.
    num_classes = len(np.unique(colors))
    palette = np.array(sns.color_palette("hls", num_classes))

    # create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')

    # add the labels for each digit corresponding to the label
    txts = []

    for i in range(num_classes):

        # Position of each label at median of data points.

        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth=5, foreground="w"),
            PathEffects.Normal()])
        txts.append(txt)

    return f, ax, sc, txts

# %%
from sklearn.manifold import TSNE
import time
time_start = time.time()
fashion_tsne = TSNE(random_state=42).fit_transform(encoded_imgs)

print( 't-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
fashion_scatter(fashion_tsne, y_val2)
# Out:
# t-SNE done! Time elapsed: 40.93775153160095 seconds
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1bdd649e3c8>,
#  <matplotlib.collections.PathCollection at 0x1bdd65574e0>,
#  [Text(-1.223753, -3.9939482, '0'), Text(2.9016795, 6.0413733, '1')])

# %%
from keras.models import load_model
encoder = load_model('AutoEncoder2_PASCAL_Deep_weights.50-0.01-0.01.hdf5')
for layer in encoder.layers:
    layer.trainable = False

# %%
encoder.layers[-13]

# %% [markdown]
# ### Section 2.3 Autoencoder+ Classification

# %%
#model = Sequential()
from keras.regularizers import L1L2
from keras.regularizers import l1
from keras.layers import Flatten
flat=Flatten()(encoder.layers[-13].output)

fully=Dense(2,  # output dim is 2, one score per each class
                activation='softmax',
                kernel_regularizer=l1(0.0001))(flat)  # input dimension = number of features your data has
modelClass = Model(inputs=encoder.input, outputs=fully)
modelClass.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
es_cb = EarlyStopping(monitor='val_acc', patience=10, verbose=1, mode='auto')
chkpt = './classifierFineTunning_PASCAL_Deep_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_acc', verbose=1, save_best_only=True, mode='auto')
modelClass.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val),callbacks=[es_cb,cp_cb])
# Out:
# Train on 467 samples, validate on 483 samples
# Epoch 1/50
# 467/467 [==============================] - 4s 9ms/step - loss: 2.6875 - acc: 0.7816 - val_loss: 2.0603 - val_acc: 0.8634
#
# Epoch 00001: val_acc improved from -inf to 0.86335, saving model to ./classifierFineTunning_PASCAL_Deep_weights.01-2.69-2.06.hdf5
# Epoch 2/50
# 467/467 [==============================] - 4s 8ms/step - loss: 1.7829 - acc: 0.8801 - val_loss: 2.1636 - val_acc: 0.8468
#
# Epoch 00002: val_acc did not improve from 0.86335
# Epoch 3/50
# 467/467 [==============================] - 4s 8ms/step - loss: 1.5259 - acc: 0.8844 - val_loss: 1.9564 - val_acc: 0.8758
#
# Epoch 00003: val_acc improved from 0.86335 to 0.87578, saving model to ./classifierFineTunning_PASCAL_Deep_weights.03-1.53-1.96.hdf5
# Epoch 4/50
# 467/467 [==============================] - 4s 8ms/step - loss: 1.5683 - acc: 0.9015 - val_loss: 2.1359 - val_acc: 0.8530
#
# Epoch 00004: val_acc did not improve from 0.87578
# Epoch 5/50
# 467/467 [==============================] - 4s 8ms/step - loss: 1.3690 - acc: 0.9036 - val_loss: 1.9093 - val_acc: 0.8758
#
# Epoch 00005: val_acc did not improve from 0.87578
# Epoch 6/50
# 467/467 [==============================] - 4s 8ms/step - loss: 1.1200 - acc: 0.9208 - val_loss: 1.9506 - val_acc: 0.8696
#
# Epoch 00006: val_acc did not improve from 0.87578
# Epoch 7/50
# 467/467 [==============================] - 4s 8ms/step - loss: 1.1650 - acc: 0.9251 - val_loss: 1.9873 - val_acc: 0.8613
#
# Epoch 00007: val_acc did not improve from 0.87578
# Epoch 8/50
# 467/467 [==============================] - 4s 8ms/step - loss: 1.1652 - acc: 0.9143 - val_loss: 1.6542 - val_acc: 0.8903
#
# Epoch 00008: val_acc improved from 0.87578 to 0.89027, saving model to ./classifierFineTunning_PASCAL_Deep_weights.08-1.17-1.65.hdf5
# Epoch 9/50
# 467/467 [==============================] - 4s 8ms/step - loss: 1.0133 - acc: 0.9379 - val_loss: 1.7562 - val_acc: 0.8841
#
# Epoch 00009: val_acc did not improve from 0.89027
# Epoch 10/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.9592 - acc: 0.9315 - val_loss: 1.4929 - val_acc: 0.9068
#
# Epoch 00010: val_acc improved from 0.89027 to 0.90683, saving model to ./classifierFineTunning_PASCAL_Deep_weights.10-0.96-1.49.hdf5
# Epoch 11/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.8559 - acc: 0.9443 - val_loss: 1.4363 - val_acc: 0.9089
#
# Epoch 00011: val_acc improved from 0.90683 to 0.90890, saving model to ./classifierFineTunning_PASCAL_Deep_weights.11-0.86-1.44.hdf5
# Epoch 12/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.7378 - acc: 0.9572 - val_loss: 1.5572 - val_acc: 0.8965
#
# Epoch 00012: val_acc did not improve from 0.90890
# Epoch 13/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.7718 - acc: 0.9465 - val_loss: 2.4224 - val_acc: 0.8302
#
# Epoch 00013: val_acc did not improve from 0.90890
# Epoch 14/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.7242 - acc: 0.9550 - val_loss: 1.5982 - val_acc: 0.8882
#
# Epoch 00014: val_acc did not improve from 0.90890
# Epoch 15/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.6920 - acc: 0.9443 - val_loss: 1.7763 - val_acc: 0.8799
#
# Epoch 00015: val_acc did not improve from 0.90890
# Epoch 16/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.6193 - acc: 0.9615 - val_loss: 1.8093 - val_acc: 0.8820
#
# Epoch 00016: val_acc did not improve from 0.90890
# Epoch 17/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.5543 - acc: 0.9679 - val_loss: 1.4911 - val_acc: 0.9006
#
# Epoch 00017: val_acc did not improve from 0.90890
# Epoch 18/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.5382 - acc: 0.9679 - val_loss: 1.5447 - val_acc: 0.8944
#
# Epoch 00018: val_acc did not improve from 0.90890
# Epoch 19/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.5022 - acc: 0.9743 - val_loss: 1.5442 - val_acc: 0.8944
#
# Epoch 00019: val_acc did not improve from 0.90890
# Epoch 20/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.5537 - acc: 0.9657 - val_loss: 1.6360 - val_acc: 0.8861
#
# Epoch 00020: val_acc did not improve from 0.90890
# Epoch 21/50
# 467/467 [==============================] - 4s 8ms/step - loss: 0.5796 - acc: 0.9615 - val_loss: 1.6330 - val_acc: 0.8861
#
# Epoch 00021: val_acc did not improve from 0.90890
# Epoch 00021: early stopping

# %%
from keras.regularizers import L1L2
from keras.layers import Flatten
flat=Flatten()(encoder.layers[-13].output)
for layer in encoder.layers:
    layer.trainable = True
fully=Dense(2,  # output dim is 2, one score per each class
                activation='softmax',
                kernel_regularizer=l1(0.0001))(flat)  # input dimension = number of features your data has
modelClass = Model(inputs=encoder.input, outputs=fully)
modelClass.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
es_cb = EarlyStopping(monitor='val_acc', patience=10, verbose=1, mode='auto')
chkpt = './classifierRetrain_PASCAL_Deep_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_acc', verbose=1, save_best_only=True, mode='auto')
modelClass.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val),callbacks=[es_cb,cp_cb])
# Out:
# Train on 467 samples, validate on 483 samples
# Epoch 1/50
# 467/467 [==============================] - 8s 18ms/step - loss: 3.8522 - acc: 0.7088 - val_loss: 2.8071 - val_acc: 0.8116
#
# Epoch 00001: val_acc improved from -inf to 0.81159, saving model to ./classifierRetrain_PASCAL_Deep_weights.01-3.85-2.81.hdf5
# Epoch 2/50
# 467/467 [==============================] - 7s 14ms/step - loss: 2.6057 - acc: 0.8266 - val_loss: 2.7222 - val_acc: 0.8157
#
# Epoch 00002: val_acc improved from 0.81159 to 0.81573, saving model to ./classifierRetrain_PASCAL_Deep_weights.02-2.61-2.72.hdf5
# Epoch 3/50
# 467/467 [==============================] - 7s 14ms/step - loss: 2.3068 - acc: 0.8458 - val_loss: 3.3252 - val_acc: 0.7805
#
# Epoch 00003: val_acc did not improve from 0.81573
# Epoch 4/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.9715 - acc: 0.8672 - val_loss: 2.7291 - val_acc: 0.8178
#
# Epoch 00004: val_acc improved from 0.81573 to 0.81781, saving model to ./classifierRetrain_PASCAL_Deep_weights.04-1.97-2.73.hdf5
# Epoch 5/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.8589 - acc: 0.8822 - val_loss: 5.8137 - val_acc: 0.6356
#
# Epoch 00005: val_acc did not improve from 0.81781
# Epoch 6/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.8270 - acc: 0.8737 - val_loss: 6.4578 - val_acc: 0.5921
#
# Epoch 00006: val_acc did not improve from 0.81781
# Epoch 7/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.5729 - acc: 0.8865 - val_loss: 1.8889 - val_acc: 0.8737
#
# Epoch 00007: val_acc improved from 0.81781 to 0.87371, saving model to ./classifierRetrain_PASCAL_Deep_weights.07-1.57-1.89.hdf5
# Epoch 8/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.3655 - acc: 0.9143 - val_loss: 2.0277 - val_acc: 0.8654
#
# Epoch 00008: val_acc did not improve from 0.87371
# Epoch 9/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.4001 - acc: 0.9079 - val_loss: 1.9358 - val_acc: 0.8758
#
# Epoch 00009: val_acc improved from 0.87371 to 0.87578, saving model to ./classifierRetrain_PASCAL_Deep_weights.09-1.40-1.94.hdf5
# Epoch 10/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.3114 - acc: 0.9165 - val_loss: 1.9205 - val_acc: 0.8675
#
# Epoch 00010: val_acc did not improve from 0.87578
# Epoch 11/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.4741 - acc: 0.8994 - val_loss: 6.1692 - val_acc: 0.6149
#
# Epoch 00011: val_acc did not improve from 0.87578
# Epoch 12/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.2834 - acc: 0.9079 - val_loss: 1.9207 - val_acc: 0.8696
#
# Epoch 00012: val_acc did not improve from 0.87578
# Epoch 13/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.1151 - acc: 0.9208 - val_loss: 4.0596 - val_acc: 0.7288
#
# Epoch 00013: val_acc did not improve from 0.87578
# Epoch 14/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.9626 - acc: 0.9400 - val_loss: 6.2654 - val_acc: 0.5983
#
# Epoch 00014: val_acc did not improve from 0.87578
# Epoch 15/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.0336 - acc: 0.9272 - val_loss: 4.6821 - val_acc: 0.7019
#
# Epoch 00015: val_acc did not improve from 0.87578
# Epoch 16/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.0160 - acc: 0.9336 - val_loss: 3.6553 - val_acc: 0.7453
#
# Epoch 00016: val_acc did not improve from 0.87578
# Epoch 17/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.7945 - acc: 0.9443 - val_loss: 5.2366 - val_acc: 0.6625
#
# Epoch 00017: val_acc did not improve from 0.87578
# Epoch 18/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.8615 - acc: 0.9422 - val_loss: 3.3868 - val_acc: 0.7826
#
# Epoch 00018: val_acc did not improve from 0.87578
# Epoch 19/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.7897 - acc: 0.9465 - val_loss: 3.0838 - val_acc: 0.8033
#
# Epoch 00019: val_acc did not improve from 0.87578
# Epoch 00019: early stopping

# %%
def reset_weights(model):
    session = K.get_session()
    for layer in model.layers: 
        if hasattr(layer, 'kernel_initializer'):
            layer.kernel.initializer.run(session=session)

for layer in encoder.layers:
    layer.trainable = True

reset_weights(encoder)

from keras.regularizers import L1L2
from keras.layers import Flatten
flat=Flatten()(encoder.layers[-13].output)

fully=Dense(2,  # output dim is 2, one score per each class
                activation='softmax',
                kernel_regularizer=l1(0.0001))(flat)  # input dimension = number of features your data has
modelClass = Model(inputs=encoder.input, outputs=fully)
modelClass.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


chkpt = './classifierRamdom_PASCAL_Deep_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_acc', verbose=1, save_best_only=True, mode='auto')
modelClass.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val),callbacks=[es_cb,cp_cb])
# Out:
# Train on 467 samples, validate on 483 samples
# Epoch 1/50
# 467/467 [==============================] - 7s 16ms/step - loss: 5.0498 - acc: 0.6424 - val_loss: 6.8697 - val_acc: 0.5611
#
# Epoch 00001: val_acc improved from -inf to 0.56108, saving model to ./classifierRamdom_PASCAL_Deep_weights.01-5.05-6.87.hdf5
# Epoch 2/50
# 467/467 [==============================] - 7s 14ms/step - loss: 2.8983 - acc: 0.8051 - val_loss: 5.6523 - val_acc: 0.6460
#
# Epoch 00002: val_acc improved from 0.56108 to 0.64596, saving model to ./classifierRamdom_PASCAL_Deep_weights.02-2.90-5.65.hdf5
# Epoch 3/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.9178 - acc: 0.8651 - val_loss: 2.5392 - val_acc: 0.8302
#
# Epoch 00003: val_acc improved from 0.64596 to 0.83023, saving model to ./classifierRamdom_PASCAL_Deep_weights.03-1.92-2.54.hdf5
# Epoch 4/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.7033 - acc: 0.8887 - val_loss: 4.7234 - val_acc: 0.7039
#
# Epoch 00004: val_acc did not improve from 0.83023
# Epoch 5/50
# 467/467 [==============================] - 7s 14ms/step - loss: 2.6195 - acc: 0.8287 - val_loss: 3.3218 - val_acc: 0.7785
#
# Epoch 00005: val_acc did not improve from 0.83023
# Epoch 6/50
# 467/467 [==============================] - 7s 14ms/step - loss: 2.1953 - acc: 0.8522 - val_loss: 6.7892 - val_acc: 0.5839
#
# Epoch 00006: val_acc did not improve from 0.83023
# Epoch 7/50
# 467/467 [==============================] - 7s 14ms/step - loss: 2.0099 - acc: 0.8694 - val_loss: 2.9143 - val_acc: 0.8095
#
# Epoch 00007: val_acc did not improve from 0.83023
# Epoch 8/50
# 467/467 [==============================] - 7s 14ms/step - loss: 2.0637 - acc: 0.8651 - val_loss: 3.6177 - val_acc: 0.7702
#
# Epoch 00008: val_acc did not improve from 0.83023
# Epoch 9/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.9695 - acc: 0.8587 - val_loss: 2.2431 - val_acc: 0.8551
#
# Epoch 00009: val_acc improved from 0.83023 to 0.85507, saving model to ./classifierRamdom_PASCAL_Deep_weights.09-1.97-2.24.hdf5
# Epoch 10/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.8787 - acc: 0.8651 - val_loss: 2.6214 - val_acc: 0.8199
#
# Epoch 00010: val_acc did not improve from 0.85507
# Epoch 11/50
# 467/467 [==============================] - 7s 15ms/step - loss: 1.6205 - acc: 0.8929 - val_loss: 2.5104 - val_acc: 0.8344
#
# Epoch 00011: val_acc did not improve from 0.85507
# Epoch 12/50
# 467/467 [==============================] - 7s 15ms/step - loss: 1.4091 - acc: 0.9058 - val_loss: 2.5872 - val_acc: 0.8261
#
# Epoch 00012: val_acc did not improve from 0.85507
# Epoch 13/50
# 467/467 [==============================] - 7s 15ms/step - loss: 1.3945 - acc: 0.9143 - val_loss: 1.8480 - val_acc: 0.8758
#
# Epoch 00013: val_acc improved from 0.85507 to 0.87578, saving model to ./classifierRamdom_PASCAL_Deep_weights.13-1.39-1.85.hdf5
# Epoch 14/50
# 467/467 [==============================] - 7s 15ms/step - loss: 1.1468 - acc: 0.9229 - val_loss: 2.4533 - val_acc: 0.8427
#
# Epoch 00014: val_acc did not improve from 0.87578
# Epoch 15/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.0050 - acc: 0.9336 - val_loss: 1.9698 - val_acc: 0.8551
#
# Epoch 00015: val_acc did not improve from 0.87578
# Epoch 16/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.9079 - acc: 0.9400 - val_loss: 1.8875 - val_acc: 0.8737
#
# Epoch 00016: val_acc did not improve from 0.87578
# Epoch 17/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.0495 - acc: 0.9315 - val_loss: 4.4650 - val_acc: 0.7060
#
# Epoch 00017: val_acc did not improve from 0.87578
# Epoch 18/50
# 467/467 [==============================] - 7s 14ms/step - loss: 1.1424 - acc: 0.9186 - val_loss: 2.0607 - val_acc: 0.8654
#
# Epoch 00018: val_acc did not improve from 0.87578
# Epoch 19/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.9736 - acc: 0.9379 - val_loss: 2.9143 - val_acc: 0.8033
#
# Epoch 00019: val_acc did not improve from 0.87578
# Epoch 20/50
# 467/467 [==============================] - 7s 15ms/step - loss: 0.9115 - acc: 0.9400 - val_loss: 1.5168 - val_acc: 0.9048
#
# Epoch 00020: val_acc improved from 0.87578 to 0.90476, saving model to ./classifierRamdom_PASCAL_Deep_weights.20-0.91-1.52.hdf5
# Epoch 21/50
# 467/467 [==============================] - 7s 15ms/step - loss: 0.9307 - acc: 0.9336 - val_loss: 2.6126 - val_acc: 0.8302
#
# Epoch 00021: val_acc did not improve from 0.90476
# Epoch 22/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.9075 - acc: 0.9400 - val_loss: 1.7971 - val_acc: 0.8799
#
# Epoch 00022: val_acc did not improve from 0.90476
# Epoch 23/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.7930 - acc: 0.9529 - val_loss: 2.1381 - val_acc: 0.8571
#
# Epoch 00023: val_acc did not improve from 0.90476
# Epoch 24/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.7074 - acc: 0.9572 - val_loss: 1.8784 - val_acc: 0.8758
#
# Epoch 00024: val_acc did not improve from 0.90476
# Epoch 25/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.6338 - acc: 0.9657 - val_loss: 1.7203 - val_acc: 0.8861
#
# Epoch 00025: val_acc did not improve from 0.90476
# Epoch 26/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.6337 - acc: 0.9615 - val_loss: 3.5952 - val_acc: 0.7578
#
# Epoch 00026: val_acc did not improve from 0.90476
# Epoch 27/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.8130 - acc: 0.9465 - val_loss: 1.6007 - val_acc: 0.8965
#
# Epoch 00027: val_acc did not improve from 0.90476
# Epoch 28/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.6094 - acc: 0.9593 - val_loss: 4.7108 - val_acc: 0.6936
#
# Epoch 00028: val_acc did not improve from 0.90476
# Epoch 29/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.6974 - acc: 0.9529 - val_loss: 2.1065 - val_acc: 0.8592
#
# Epoch 00029: val_acc did not improve from 0.90476
# Epoch 30/50
# 467/467 [==============================] - 7s 14ms/step - loss: 0.6832 - acc: 0.9572 - val_loss: 1.8885 - val_acc: 0.8654
#
# Epoch 00030: val_acc did not improve from 0.90476
# Epoch 00030: early stopping

# %%
from sklearn.manifold import TSNE
import time
time_start = time.time()
encoded_imgs = encoder.predict(x_val)
print(encoded_imgs.shape)
encoded_imgs = encoded_imgs.reshape((len(encoded_imgs), np.prod(encoded_imgs.shape[1:])))
print(encoded_imgs.shape)


time_start = time.time()
fashion_tsne = TSNE(random_state=42).fit_transform(encoded_imgs)

print( 't-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
fashion_scatter(fashion_tsne, y_val2)
# Out:
# (483, 16, 16, 300)
# (483, 76800)
# t-SNE done! Time elapsed: 36.356356620788574 seconds
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x28654258f98>,
#  <matplotlib.collections.PathCollection at 0x28653753c50>,
#  [Text(3.3689537, -2.708327, '0'), Text(-3.1181965, 5.208045, '1')])

# %%
print(modelClass.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 128, 128, 3)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 64, 128)       9728
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 512)         1180160
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4, 4, 2)           1026
# =================================================================
# Total params: 1,489,666
# Trainable params: 1,026
# Non-trainable params: 1,488,640
# _________________________________________________________________
# None

# %% [markdown]
# ### Section 3 - Segmentation

# %%
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from skimage.io import imread, imshow, concatenate_images
from keras.layers.merge import concatenate, add



def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

input_img = Input(shape=(image_size, image_size, 3))
n_filters=16 
dropout=0.05
batchnorm=True
# contracting path
c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
p1 = MaxPooling2D((2, 2)) (c1)
p1 = Dropout(dropout*0.5)(p1)

c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
p2 = MaxPooling2D((2, 2)) (c2)
p2 = Dropout(dropout)(p2)

c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
p3 = MaxPooling2D((2, 2)) (c3)
p3 = Dropout(dropout)(p3)

#c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
#p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
#p4 = Dropout(dropout)(p4)

c5 = conv2d_block(p3, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)

# expansive path
#u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
#u6 = concatenate([u6, c4])
#u6 = Dropout(dropout)(u6)
#c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c5)
u7 = concatenate([u7, c3])
u7 = Dropout(dropout)(u7)
c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
u8 = Dropout(dropout)(u8)
c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
u9 = Dropout(dropout)(u9)
c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)
model = Model(inputs=[input_img], outputs=[outputs])


model.compile(optimizer='adadelta', loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 256, 256, 16) 448         input_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 256, 256, 16) 64          conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 256, 256, 16) 0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 256, 256, 16) 2320        activation_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 256, 256, 16) 64          conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 256, 256, 16) 0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 128, 128, 16) 0           activation_120[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 128, 128, 16) 0           max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 128, 128, 32) 4640        dropout_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 128, 128, 32) 128         conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 128, 128, 32) 0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 128, 128, 32) 9248        activation_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 128, 128, 32) 128         conv2d_126[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 128, 128, 32) 0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 64, 64, 32)   0           activation_122[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 64, 64, 32)   0           max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 64, 64, 64)   18496       dropout_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 64, 64, 64)   256         conv2d_127[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 64, 64, 64)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 64, 64, 64)   36928       activation_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 64, 64, 64)   256         conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 64, 64, 64)   0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 32, 32, 64)   0           activation_124[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 32, 32, 64)   0           max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 32, 32, 256)  147712      dropout_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 32, 32, 256)  1024        conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 32, 32, 256)  0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 32, 32, 256)  590080      activation_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 32, 32, 256)  1024        conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 32, 32, 256)  0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 64, 64, 64)   147520      activation_126[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 64, 64, 128)  0           conv2d_transpose_21[0][0]
#                                                                  activation_124[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 64, 64, 128)  0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 64, 64, 64)   73792       dropout_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 64, 64, 64)   256         conv2d_131[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 64, 64, 64)   0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 64, 64, 64)   36928       activation_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 64, 64, 64)   256         conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 64, 64, 64)   0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 128, 128, 32) 18464       activation_128[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 128, 128, 64) 0           conv2d_transpose_22[0][0]
#                                                                  activation_122[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 128, 128, 64) 0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 128, 128, 32) 18464       dropout_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 128, 128, 32) 128         conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 128, 128, 32) 0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 128, 128, 32) 9248        activation_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 128, 128, 32) 128         conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 128, 128, 32) 0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 256, 256, 16) 4624        activation_130[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 256, 256, 32) 0           conv2d_transpose_23[0][0]
#                                                                  activation_120[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 256, 256, 32) 0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 256, 256, 16) 4624        dropout_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 256, 256, 16) 64          conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 256, 256, 16) 0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 256, 256, 16) 2320        activation_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 256, 256, 16) 64          conv2d_136[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 256, 256, 16) 0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 256, 256, 1)  17          activation_132[0][0]
# ==================================================================================================
# Total params: 1,129,713
# Trainable params: 1,127,793
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-tgs-salt.h5', verbose=1, save_best_only=True, save_weights_only=True)
]
results = model.fit(x_train_mask, mask_train, batch_size=5, epochs=100, callbacks=callbacks,
                    validation_data=(x_val_mask, mask_val))
# Out:
# Train on 48 samples, validate on 53 samples
# Epoch 1/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2543 - acc: 0.7556 - val_loss: 0.2389 - val_acc: 0.7902
#
# Epoch 00001: val_loss improved from inf to 0.23891, saving model to model-tgs-salt.h5
# Epoch 2/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2546 - acc: 0.7556 - val_loss: 0.2389 - val_acc: 0.7901
#
# Epoch 00002: val_loss improved from 0.23891 to 0.23887, saving model to model-tgs-salt.h5
# Epoch 3/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2547 - acc: 0.7555 - val_loss: 0.2388 - val_acc: 0.7900
#
# Epoch 00003: val_loss improved from 0.23887 to 0.23881, saving model to model-tgs-salt.h5
# Epoch 4/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2557 - acc: 0.7555 - val_loss: 0.2388 - val_acc: 0.7900
#
# Epoch 00004: val_loss did not improve from 0.23881
# Epoch 5/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2559 - acc: 0.7555 - val_loss: 0.2388 - val_acc: 0.7900
#
# Epoch 00005: val_loss improved from 0.23881 to 0.23877, saving model to model-tgs-salt.h5
# Epoch 6/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2564 - acc: 0.7554 - val_loss: 0.2387 - val_acc: 0.7900
#
# Epoch 00006: val_loss improved from 0.23877 to 0.23870, saving model to model-tgs-salt.h5
# Epoch 7/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2536 - acc: 0.7556 - val_loss: 0.2385 - val_acc: 0.7899
#
# Epoch 00007: val_loss improved from 0.23870 to 0.23851, saving model to model-tgs-salt.h5
# Epoch 8/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2564 - acc: 0.7556 - val_loss: 0.2385 - val_acc: 0.7899
#
# Epoch 00008: val_loss improved from 0.23851 to 0.23850, saving model to model-tgs-salt.h5
# Epoch 9/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2538 - acc: 0.7555 - val_loss: 0.2384 - val_acc: 0.7899
#
# Epoch 00009: val_loss improved from 0.23850 to 0.23838, saving model to model-tgs-salt.h5
# Epoch 10/100
# 48/48 [==============================] - 5s 96ms/step - loss: 0.2575 - acc: 0.7555 - val_loss: 0.2383 - val_acc: 0.7899
#
# Epoch 00010: val_loss improved from 0.23838 to 0.23833, saving model to model-tgs-salt.h5
# Epoch 11/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2508 - acc: 0.7556 - val_loss: 0.2382 - val_acc: 0.7899
#
# Epoch 00011: val_loss improved from 0.23833 to 0.23816, saving model to model-tgs-salt.h5
# Epoch 12/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2528 - acc: 0.7556 - val_loss: 0.2381 - val_acc: 0.7899
#
# Epoch 00012: val_loss improved from 0.23816 to 0.23811, saving model to model-tgs-salt.h5
# Epoch 13/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2569 - acc: 0.7557 - val_loss: 0.2380 - val_acc: 0.7899
#
# Epoch 00013: val_loss improved from 0.23811 to 0.23799, saving model to model-tgs-salt.h5
# Epoch 14/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2528 - acc: 0.7555 - val_loss: 0.2380 - val_acc: 0.7898
#
# Epoch 00014: val_loss did not improve from 0.23799
# Epoch 15/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2537 - acc: 0.7555 - val_loss: 0.2380 - val_acc: 0.7897
#
# Epoch 00015: val_loss did not improve from 0.23799
# Epoch 16/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2541 - acc: 0.7556 - val_loss: 0.2380 - val_acc: 0.7897
#
# Epoch 00016: val_loss did not improve from 0.23799
# Epoch 17/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2565 - acc: 0.7556 - val_loss: 0.2380 - val_acc: 0.7897
#
# Epoch 00017: val_loss improved from 0.23799 to 0.23797, saving model to model-tgs-salt.h5
# Epoch 18/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2569 - acc: 0.7555 - val_loss: 0.2379 - val_acc: 0.7897
#
# Epoch 00018: val_loss improved from 0.23797 to 0.23788, saving model to model-tgs-salt.h5
# Epoch 19/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2561 - acc: 0.7556 - val_loss: 0.2379 - val_acc: 0.7897
#
# Epoch 00019: val_loss did not improve from 0.23788
# Epoch 20/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2569 - acc: 0.7556 - val_loss: 0.2380 - val_acc: 0.7897
#
# Epoch 00020: val_loss did not improve from 0.23788
# Epoch 21/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2558 - acc: 0.7556 - val_loss: 0.2379 - val_acc: 0.7897
#
# Epoch 00021: val_loss did not improve from 0.23788
# Epoch 22/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2549 - acc: 0.7556 - val_loss: 0.2379 - val_acc: 0.7897
#
# Epoch 00022: val_loss did not improve from 0.23788
# Epoch 23/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2527 - acc: 0.7556 - val_loss: 0.2378 - val_acc: 0.7896
#
# Epoch 00023: val_loss improved from 0.23788 to 0.23783, saving model to model-tgs-salt.h5
# Epoch 24/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2580 - acc: 0.7556 - val_loss: 0.2379 - val_acc: 0.7896
#
# Epoch 00024: val_loss did not improve from 0.23783
# Epoch 25/100
# 48/48 [==============================] - 5s 96ms/step - loss: 0.2512 - acc: 0.7556 - val_loss: 0.2379 - val_acc: 0.7896
#
# Epoch 00025: val_loss did not improve from 0.23783
# Epoch 26/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2539 - acc: 0.7555 - val_loss: 0.2378 - val_acc: 0.7896
#
# Epoch 00026: val_loss improved from 0.23783 to 0.23778, saving model to model-tgs-salt.h5
# Epoch 27/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2540 - acc: 0.7556 - val_loss: 0.2376 - val_acc: 0.7896
#
# Epoch 00027: val_loss improved from 0.23778 to 0.23765, saving model to model-tgs-salt.h5
# Epoch 28/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2546 - acc: 0.7555 - val_loss: 0.2377 - val_acc: 0.7896
#
# Epoch 00028: val_loss did not improve from 0.23765
# Epoch 29/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2581 - acc: 0.7557 - val_loss: 0.2377 - val_acc: 0.7897
#
# Epoch 00029: val_loss did not improve from 0.23765
# Epoch 30/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2545 - acc: 0.7557 - val_loss: 0.2377 - val_acc: 0.7897
#
# Epoch 00030: val_loss did not improve from 0.23765
# Epoch 31/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2510 - acc: 0.7556 - val_loss: 0.2377 - val_acc: 0.7896
#
# Epoch 00031: val_loss did not improve from 0.23765
# Epoch 32/100
# 48/48 [==============================] - 5s 94ms/step - loss: 0.2537 - acc: 0.7555 - val_loss: 0.2376 - val_acc: 0.7896
#
# Epoch 00032: val_loss improved from 0.23765 to 0.23762, saving model to model-tgs-salt.h5
# Epoch 33/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2552 - acc: 0.7555 - val_loss: 0.2376 - val_acc: 0.7896
#
# Epoch 00033: val_loss improved from 0.23762 to 0.23757, saving model to model-tgs-salt.h5
# Epoch 34/100
# 48/48 [==============================] - 5s 94ms/step - loss: 0.2528 - acc: 0.7556 - val_loss: 0.2376 - val_acc: 0.7896
#
# Epoch 00034: val_loss improved from 0.23757 to 0.23755, saving model to model-tgs-salt.h5
# Epoch 35/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2551 - acc: 0.7556 - val_loss: 0.2376 - val_acc: 0.7896
#
# Epoch 00035: val_loss did not improve from 0.23755
# Epoch 36/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2552 - acc: 0.7555 - val_loss: 0.2376 - val_acc: 0.7896
#
# Epoch 00036: val_loss did not improve from 0.23755
# Epoch 37/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2555 - acc: 0.7555 - val_loss: 0.2376 - val_acc: 0.7895
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
#
# Epoch 00037: val_loss did not improve from 0.23755
# Epoch 38/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2543 - acc: 0.7556 - val_loss: 0.2375 - val_acc: 0.7896
#
# Epoch 00038: val_loss improved from 0.23755 to 0.23751, saving model to model-tgs-salt.h5
# Epoch 39/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2561 - acc: 0.7556 - val_loss: 0.2375 - val_acc: 0.7896
#
# Epoch 00039: val_loss improved from 0.23751 to 0.23751, saving model to model-tgs-salt.h5
# Epoch 40/100
# 48/48 [==============================] - 5s 96ms/step - loss: 0.2561 - acc: 0.7556 - val_loss: 0.2375 - val_acc: 0.7896
#
# Epoch 00040: val_loss improved from 0.23751 to 0.23749, saving model to model-tgs-salt.h5
# Epoch 41/100
# 48/48 [==============================] - 5s 96ms/step - loss: 0.2540 - acc: 0.7556 - val_loss: 0.2374 - val_acc: 0.7896
#
# Epoch 00041: val_loss improved from 0.23749 to 0.23743, saving model to model-tgs-salt.h5
# Epoch 42/100
# 48/48 [==============================] - 5s 96ms/step - loss: 0.2532 - acc: 0.7556 - val_loss: 0.2373 - val_acc: 0.7896
#
# Epoch 00042: val_loss improved from 0.23743 to 0.23732, saving model to model-tgs-salt.h5
# Epoch 43/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2576 - acc: 0.7554 - val_loss: 0.2374 - val_acc: 0.7896
#
# Epoch 00043: val_loss did not improve from 0.23732
# Epoch 44/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2535 - acc: 0.7556 - val_loss: 0.2376 - val_acc: 0.7895
#
# Epoch 00044: val_loss did not improve from 0.23732
# Epoch 45/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2536 - acc: 0.7555 - val_loss: 0.2376 - val_acc: 0.7895
#
# Epoch 00045: val_loss did not improve from 0.23732
# Epoch 46/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2560 - acc: 0.7554 - val_loss: 0.2377 - val_acc: 0.7894
#
# Epoch 00046: val_loss did not improve from 0.23732
# Epoch 47/100
# 48/48 [==============================] - 5s 97ms/step - loss: 0.2531 - acc: 0.7555 - val_loss: 0.2377 - val_acc: 0.7894
#
# Epoch 00047: val_loss did not improve from 0.23732
# Epoch 48/100
# 48/48 [==============================] - 5s 98ms/step - loss: 0.2541 - acc: 0.7556 - val_loss: 0.2377 - val_acc: 0.7894
#
# Epoch 00048: val_loss did not improve from 0.23732
# Epoch 49/100
# 48/48 [==============================] - 5s 98ms/step - loss: 0.2589 - acc: 0.7556 - val_loss: 0.2377 - val_acc: 0.7894
#
# Epoch 00049: val_loss did not improve from 0.23732
# Epoch 50/100
# 48/48 [==============================] - 5s 99ms/step - loss: 0.2560 - acc: 0.7556 - val_loss: 0.2376 - val_acc: 0.7894
#
# Epoch 00050: val_loss did not improve from 0.23732
# Epoch 51/100
# 48/48 [==============================] - 5s 96ms/step - loss: 0.2551 - acc: 0.7555 - val_loss: 0.2375 - val_acc: 0.7895
#
# Epoch 00051: val_loss did not improve from 0.23732
# Epoch 52/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.2545 - acc: 0.7555 - val_loss: 0.2376 - val_acc: 0.7895
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00052: val_loss did not improve from 0.23732
# Epoch 00052: early stopping

# %%
preds_train = model.predict(x_train_mask, verbose=1)
preds_val = model.predict(x_val_mask, verbose=1)
#preds_train_t = (preds_train > 0.5).astype(np.uint8)
#preds_val_t = (preds_val < 0.001).astype(np.uint8)
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_val_mask[i].reshape(image_size, image_size,3)) 
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(preds_val[i].reshape(image_size, image_size) )
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 48/48 [==============================] - 1s 22ms/step
# 53/53 [==============================] - 1s 18ms/step
